# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>   My jupyter notebook on IBM Watson Studio

# %% [markdown]
# <b>Amisha Sanjay Sonone</b>
#
# Data scientist

# %% [markdown]
# <i>I am interested in data science because , it will help me understand the market as i am interested in finance marketing. With the help of Data science i can build strategies for analysing data and get the productive outcome.</i>

# %% [markdown]
# <h3>Following code print the sum of two numbers.

# %%
a=2
b=4
print(a+b)

# %% [markdown]
# <ul>
# <li>Maths</li>
# <li>Science</li>
# <li>English</li>
# </ul>
#
# <ol>
# <li>Maths</li>
# <li>Science</li>
# <li>English</li>
# </ol>
#
# <p>This is Amisha Sonone.</p>
# <hr>
# <p>I am from India.</p>
